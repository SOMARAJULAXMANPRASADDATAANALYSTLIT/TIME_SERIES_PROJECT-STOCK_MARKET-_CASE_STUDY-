# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

### so that u dont have warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ##### The tech stocks we'll use for this analysis

# %%
path=r'C:\Users\somar\OneDrive - Technological University of the Shannon Midwest\data anaytics projects\2-Time Series Data Analysis-20221224T215736Z-001\2-Time Series Data Analysis\individual_stocks_5yr'
company_list = ['AAPL_data.csv', 'GOOG_data.csv', 'MSFT_data.csv', 'AMZN_data.csv']

#blank dataframe
all_data = pd.DataFrame()

for file in company_list:
    current_df = pd.read_csv(path+"/"+file)
    all_data = pd.concat([all_data, current_df])
    
all_data.shape
# Out:
# (4752, 7)

# %%
all_data.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
all_data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
all_data['date']=pd.to_datetime(all_data['date'])

# %%
all_data['date'][0]
# Out:
# 0   2013-02-08
# 0   2014-03-27
# 0   2013-02-08
# 0   2013-02-08
# Name: date, dtype: datetime64[ns]

# %%
all_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %% [markdown]
# # Analyse closing price of all the stocks

# %%
tech_list = all_data['Name'].unique()

# %% [markdown]
# This code creates a figure with a grid of subplots, with 2 rows and 2 columns. The size of the figure is set to 20 inches in width and 12 inches in height using the figsize parameter.
#
# Then, a loop is used to iterate over the tech_list list, which is assumed to contain the names of some companies. For each company, a subplot is created within the grid using the subplot function. The subplot is specified by its position in the grid, which is determined by the loop counter i and the number of rows and columns of the grid.
#
# Inside the loop, a dataframe called df is created that contains only the rows of the all_data dataframe that correspond to the current company. Then, a line plot is created using the plot function, with the dates on the x-axis and the closing prices on the y-axis. The plot is given a title using the title function.
#
# Finally, the code will create a separate subplot for each company in the tech_list list and plot the closing prices for each company on its own subplot.

# %%
plt.figure(figsize=(20,12))
for i, company in enumerate(tech_list,1):
    plt.subplot(2, 2, i)
    df=all_data[all_data['Name']==company]
    plt.plot(df['date'],df['close'])
    plt.title(company)

# %% [markdown]
# # let's analyse the total volume of stock being traded each day

# %%
plt.figure(figsize=(20,12))
for i, company in enumerate(tech_list,1):
    plt.subplot(2, 2, i)
    df=all_data[all_data['Name']==company]
    plt.plot(df['date'],df['volume'])
    plt.title(company)

# %% [markdown]
# # using plotly

# %%
import plotly.express as px

# %%
for company in (tech_list):
    df=all_data[all_data['Name']==company]
    fig = px.line(df, x="date", y="volume", title=company)
    fig.show()
# Out:
# <div>                            <div id="972e3339-3fbf-4204-8b1e-81ebf4537a17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("972e3339-3fbf-4204-8b1e-81ebf4537a17")) {                    Plotly.newPlot(                        "972e3339-3fbf-4204-8b1e-81ebf4537a17",                        [{"hovertemplate":"date=%{x}<br>volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-0
# ...

# %%
all_data['Name'].unique()
# Out:
# array(['AAPL', 'GOOG', 'MSFT', 'AMZN'], dtype=object)

# %% [markdown]
# ##### analyse Daily price change in stock

# %% [markdown]
# ##### Daily Stock Return Formula
#     To calculate how much you gained or lost per day for a stock, subtract the opening price from the closing price. Then, multiply the result by the number of shares you own in the company.

# %%
df=pd.read_csv(r'C:\Users\somar\OneDrive - Technological University of the Shannon Midwest\data anaytics projects\2-Time Series Data Analysis-20221224T215736Z-001\2-Time Series Data Analysis\individual_stocks_5yr/AAPL_data.csv')
df.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %% [markdown]
# ##### percentage return

# %%
df['1day % return']=((df['close']-df['open'])/df['close'])*100
df.head()
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    1day % return
# 0       0.206325
# 1       0.714688
# 2      -2.481344
# 3      -0.042869
# 4       0.443624

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name',
#        '1day % return'],
#       dtype='object')

# %% [markdown]
# ##### using plotly to visualise data

# %%
import plotly.express as px
fig = px.line(df, x="date", y="1day % return", title='')
fig.show()
# Out:
# <div>                            <div id="336e5c94-4ab8-4904-bf2d-f33ec53f9e00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("336e5c94-4ab8-4904-bf2d-f33ec53f9e00")) {                    Plotly.newPlot(                        "336e5c94-4ab8-4904-bf2d-f33ec53f9e00",                        [{"hovertemplate":"date=%{x}<br>1day % return=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08","2013-02-11","2013-02-12","2013-02-13","2013-02-14","2013-02-15","2013-02-19","2013-02-20","2013-02-21","2013-02-22","2013-02-25","2013-02-26","2013-02-27","2013-02-28","2013-03-01","2013-03-04","2013-03-05","2013-03-06","2013-03-07","2013-03-08","201
# ...

# %% [markdown]
# ##### using matplotlib for visualisation

# %%
plt.figure(figsize=(10,6))
df['1day % return'].plot()

# %% [markdown]
# #### lets say between some interval

# %%
df.set_index('date')['2016-01-01':'2016-03-31']['1day % return'].plot()
plt.xticks(rotation='vertical')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.,  70.]),
#  [Text(-10.0, 0, '2016-03-17'),
#   Text(0.0, 0, '2016-01-04'),
#   Text(10.0, 0, '2016-01-19'),
#   Text(20.0, 0, '2016-02-02'),
#   Text(30.0, 0, '2016-02-17'),
#   Text(40.0, 0, '2016-03-02'),
#   Text(50.0, 0, '2016-03-16'),
#   Text(60.0, 0, '2016-03-31'),
#   Text(70.0, 0, '')])

# %% [markdown]
# #### Analyse monthly mean of close column

# %%
df2=df.copy()

# %%
df2['date']=pd.to_datetime(df2['date'])

# %%
df2.set_index('date',inplace=True)

# %%
df2.head()
# Out:
#               open    high      low   close   volume  Name
# date
# 2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN
# 2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN
# 2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN
# 2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN
# 2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN

# %%
df2['close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ##### resampling close column year wise

# %%
df2['close'].resample('Y').mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ##### Checking if the Stock prices of these tech companies(Amazon,Apple,Google,Microsoft) are correlated

# %%
df2.head()
# Out:
#                open     high      low    close     volume  Name  1day % return
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL       0.206325
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL       0.714688
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL      -2.481344
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL      -0.042869
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL       0.443624

# %% [markdown]
# ##### reading data of tech companies

# %%
aapl=pd.read_csv(r'C:\Users\somar\OneDrive - Technological University of the Shannon Midwest\data anaytics projects\2-Time Series Data Analysis-20221224T215736Z-001\2-Time Series Data Analysis\individual_stocks_5yr\AAPL_data.csv')
aapl.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
goog=pd.read_csv(r'C:\Users\somar\OneDrive - Technological University of the Shannon Midwest\data anaytics projects\2-Time Series Data Analysis-20221224T215736Z-001\2-Time Series Data Analysis\individual_stocks_5yr/GOOG_data.csv')
goog.head()
# Out:
#          date     open    high     low   close  volume  Name
# 0  2014-03-27  568.000  568.00  552.92  558.46   13052  GOOG
# 1  2014-03-28  561.200  566.43  558.67  559.99   41003  GOOG
# 2  2014-03-31  566.890  567.00  556.93  556.97   10772  GOOG
# 3  2014-04-01  558.710  568.45  558.71  567.16    7932  GOOG
# 4  2014-04-02  565.106  604.83  562.19  567.00  146697  GOOG

# %%
amzn=pd.read_csv(r'C:\Users\somar\OneDrive - Technological University of the Shannon Midwest\data anaytics projects\2-Time Series Data Analysis-20221224T215736Z-001\2-Time Series Data Analysis\individual_stocks_5yr/AMZN_data.csv')
amzn.head()
# Out:
#          date    open    high      low   close   volume  Name
# 0  2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN
# 1  2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN
# 2  2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN
# 3  2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN
# 4  2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN

# %%
msft=pd.read_csv(r'C:\Users\somar\OneDrive - Technological University of the Shannon Midwest\data anaytics projects\2-Time Series Data Analysis-20221224T215736Z-001\2-Time Series Data Analysis\individual_stocks_5yr/MSFT_data.csv')
msft.head()
# Out:
#          date   open   high    low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
### create a blank dataframe
close=pd.DataFrame()

# %%
close['aapl']=aapl['close']
close['goog']=goog['close']
close['amzn']=amzn['close']
close['msft']=msft['close']

# %%
close.head()
# Out:
#       aapl    goog    amzn   msft
# 0  67.8542  558.46  261.95  27.55
# 1  68.5614  559.99  257.21  27.86
# 2  66.8428  556.97  258.70  27.88
# 3  66.7156  567.16  269.47  28.03
# 4  66.6556  567.00  269.24  28.04

# %% [markdown]
# #### Multi-variate Analysis

# %%
sns.pairplot(data=close)

# %% [markdown]
# ##### co-relation plot for stock prices

# %%
sns.heatmap(close.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### Closing price of Google and Microsoft are well correlated
#        and Closing price of Amazon and Microsoft have a co-relation of 0.96

# %% [markdown]
# ##### Analyse Daily return of each stock & how they are co-related

# %%
data=pd.DataFrame()

# %%
aapl.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
data['appl_change']=((aapl['close']-aapl['open'])/aapl['close'])*100
data['goog_change']=((goog['close']-goog['open'])/goog['close'])*100
data['amzn_change']=((amzn['close']-amzn['open'])/amzn['close'])*100
data['msft_change']=((msft['close']-msft['open'])/msft['close'])*100

# %%
data.head()
# Out:
#    appl_change  goog_change  amzn_change  msft_change
# 0     0.206325    -1.708269     0.209964     0.725953
# 1     0.714688    -0.216075    -2.328836     0.753769
# 2    -2.481344    -1.781065    -0.189409     0.000000
# 3    -0.042869     1.489879     2.946525     0.356761
# 4     0.443624     0.334039     0.694548     0.427960

# %%
sns.pairplot(data=data)

# %% [markdown]
# ##### Correlation plot for daily returns

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### We can see that Amazon and microsoft have good correlation on daily returns

# %%
data.head()
# Out:
#    appl_change  goog_change  amzn_change  msft_change
# 0     0.206325    -1.708269     0.209964     0.725953
# 1     0.714688    -0.216075    -2.328836     0.753769
# 2    -2.481344    -1.781065    -0.189409     0.000000
# 3    -0.042869     1.489879     2.946525     0.356761
# 4     0.443624     0.334039     0.694548     0.427960

# %%
data.columns
# Out:
# Index(['appl_change', 'goog_change', 'amzn_change', 'msft_change'], dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Value at Risk analysis for Apple

# %%
import seaborn as sns

# %%
sns.distplot(data['appl_change'])
# Out:
# <AxesSubplot:xlabel='appl_change', ylabel='Density'>

# %% [markdown]
# ##### it somehow follows a normal distribution

# %%
data['appl_change'].std()
# Out:
# 1.1871377131421237

# %%
data['appl_change'].quantile(0.1)
# Out:
# -1.4246644227944307

# %% [markdown]
# ##### 1.4246644227944307 means that 90% of the times the worst daily Loss will not exceed 1.42

# %%
data.describe().T
# Out:
#               count      mean       std       min       25%       50%  \
# appl_change  1259.0 -0.000215  1.187138 -7.104299 -0.658021  0.042230
# goog_change   975.0 -0.012495  1.092560 -5.952266 -0.551963  0.024951
# amzn_change  1259.0 -0.000398  1.358679 -9.363077 -0.738341 -0.002623
# msft_change  1259.0  0.076404  1.059260 -5.177618 -0.509241  0.061069
#
#                   75%       max
# appl_change  0.715427  8.000388
# goog_change  0.672649  4.943550
# amzn_change  0.852568  5.640265
# msft_change  0.703264  4.861491
